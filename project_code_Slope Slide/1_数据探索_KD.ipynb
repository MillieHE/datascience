# %%
import pandas as pd
import numpy as np
import os
os.chdir(r'\KD_TP3-29_pre_result')##############adjust

# %% [markdown]
# # 数据导入

# %%
data_name=os.listdir(r'\KD_TP3-29_pre_result')##############adjust
TP10=pd.read_csv(data_name[0],encoding='utf-8')
TP11=pd.read_csv(data_name[1],encoding='utf-8')
TP12=pd.read_csv(data_name[2],encoding='utf-8')
TP13=pd.read_csv(data_name[3],encoding='utf-8')
TP14=pd.read_csv(data_name[4],encoding='utf-8')
TP15=pd.read_csv(data_name[5],encoding='utf-8')
TP18=pd.read_csv(data_name[6],encoding='utf-8')
TP19=pd.read_csv(data_name[7],encoding='utf-8')
TP20=pd.read_csv(data_name[8],encoding='utf-8')
TP21=pd.read_csv(data_name[9],encoding='utf-8')
TP22=pd.read_csv(data_name[10],encoding='utf-8')


#全时间链
date=pd.DataFrame(pd.date_range(TP10.iloc[0][0],TP10.iloc[-1][0],freq='1D'))
date.columns=['date']
date['date']=date['date'].map(lambda x:x.strftime('%Y-%m-%d'))

#others
TP23=pd.read_csv(data_name[11],encoding='utf-8')
TP23=date.merge(TP23,how='left',on='date')

TP25=pd.read_csv(data_name[12],encoding='utf-8')
TP25=date.merge(TP25,how='left',on='date')

TP26=pd.read_csv(data_name[13],encoding='utf-8')
TP26=date.merge(TP26,how='left',on='date')

TP27=pd.read_csv(data_name[14],encoding='utf-8')
TP27=date.merge(TP27,how='left',on='date')

TP28=pd.read_csv(data_name[15],encoding='utf-8')
TP28=date.merge(TP28,how='left',on='date')

TP29=pd.read_csv(data_name[16],encoding='utf-8')
TP29=date.merge(TP29,how='left',on='date')

TP3=pd.read_csv(data_name[17],encoding='utf-8')
TP5=pd.read_csv(data_name[18],encoding='utf-8')
TP8=pd.read_csv(data_name[19],encoding='utf-8')
TP9=pd.read_csv(data_name[20],encoding='utf-8')

#时间转换
TP3['date']=pd.to_datetime(TP3['date'])
TP5['date']=pd.to_datetime(TP5['date'])
TP8['date']=pd.to_datetime(TP8['date'])
TP9['date']=pd.to_datetime(TP9['date'])
TP10['date']=pd.to_datetime(TP10['date'])
TP11['date']=pd.to_datetime(TP11['date'])
TP12['date']=pd.to_datetime(TP12['date'])
TP13['date']=pd.to_datetime(TP13['date'])
TP14['date']=pd.to_datetime(TP14['date'])
TP15['date']=pd.to_datetime(TP15['date'])
TP18['date']=pd.to_datetime(TP18['date'])
TP19['date']=pd.to_datetime(TP19['date'])
TP20['date']=pd.to_datetime(TP20['date'])
TP21['date']=pd.to_datetime(TP21['date'])
TP22['date']=pd.to_datetime(TP22['date'])
TP23['date']=pd.to_datetime(TP23['date'])
TP25['date']=pd.to_datetime(TP25['date'])
TP26['date']=pd.to_datetime(TP26['date'])
TP27['date']=pd.to_datetime(TP27['date'])
TP28['date']=pd.to_datetime(TP28['date'])
TP29['date']=pd.to_datetime(TP29['date'])

# %% [markdown]
# # 各点号，时间图

# %%
import matplotlib.pyplot as plt
TP23.set_index('date')[['sum_xy']].plot()
TP23.set_index('date')[['x','y','z']].plot()
TP23.set_index('date')[['x','y','z','sum_xy']].plot()
TP23.set_index('date').plot()

# %% [markdown]
# # 多点号时间图

# %% [markdown]
# ## 坡面累计位移

# %% [markdown]
# ### 整体

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))

plt.plot(TP3.date,TP3['sum_xy'],label='TP3')
plt.plot(TP5.date,TP5['sum_xy'],label='TP5')
plt.plot(TP8.date,TP8['sum_xy'],label='TP8')
plt.plot(TP9.date,TP9['sum_xy'],label='TP9')
plt.plot(TP10.date,TP10['sum_xy'],label='TP10')
plt.plot(TP11.date,TP11['sum_xy'],label='TP11')
plt.plot(TP12.date,TP12['sum_xy'],label='TP12')
plt.plot(TP13.date,TP13['sum_xy'],label='TP13')
plt.plot(TP14.date,TP14['sum_xy'],label='TP14')
plt.plot(TP15.date,TP15['sum_xy'],label='TP15')
plt.plot(TP18.date,TP18['sum_xy'],label='TP18')
plt.plot(TP19.date,TP19['sum_xy'],label='TP19')
plt.plot(TP20.date,TP20['sum_xy'],label='TP20')
plt.plot(TP21.date,TP21['sum_xy'],label='TP21')
plt.plot(TP22.date,TP22['sum_xy'],label='TP22')
plt.plot(TP23.date,TP23['sum_xy'],label='TP23')
plt.plot(TP23.date,TP25['sum_xy'],label='TP25')
plt.plot(TP23.date,TP26['sum_xy'],label='TP26')
plt.plot(TP23.date,TP27['sum_xy'],label='TP27')
plt.plot(TP23.date,TP28['sum_xy'],label='TP28')
plt.plot(TP23.date,TP29['sum_xy'],label='TP29')

plt.legend()

#图像导出
plt.savefig(r'\KD_pic_\KD_xy.png',bbox_inches='tight',dpi = 1000)##############adjust

# %% [markdown]
# ### TP8

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))

plt.plot(TP8.date,TP8['sum_xy'],label='TP8')

plt.legend()

#图像导出
plt.savefig(r'\KD_pic_\KD_TP8.png',bbox_inches='tight',dpi = 1000)##############adjust

# %% [markdown]
# ### TP22

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))

plt.plot(TP22.date,TP22['sum_xy'],label='TP22')

plt.legend()

#图像导出
plt.savefig(r'\KD_pic_\KD_TP22.png',bbox_inches='tight',dpi = 1000)##############adjust

# %% [markdown]
# ### TP15

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))

plt.plot(TP15.date,TP15['sum_xy'],label='TP15')

plt.legend()

#图像导出
plt.savefig(r'\KD_pic_\KD_TP15.png',bbox_inches='tight',dpi = 1000)##############adjust

# %% [markdown]
# ### TP8、TP22、TP15

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))

plt.plot(TP8.date,TP8['sum_xy'],label='TP8')
plt.plot(TP22.date,TP22['sum_xy'],label='TP22')
plt.plot(TP15.date,TP15['sum_xy'],label='TP15')

plt.legend()

#图像导出
plt.savefig(r'\KD_pic_\KD_3lines.png',bbox_inches='tight',dpi = 1000)##############adjust

# %% [markdown]
# ## 坡面相对位移

# %%
plt.figure(figsize=(12,8))

plt.plot(TP3.date,TP3['dis_xy'],label='TP3')
plt.plot(TP5.date,TP5['dis_xy'],label='TP5')
plt.plot(TP8.date,TP8['dis_xy'],label='TP8')
plt.plot(TP9.date,TP9['dis_xy'],label='TP9')
plt.plot(TP10.date,TP10['dis_xy'],label='TP10')
plt.plot(TP11.date,TP11['dis_xy'],label='TP11')
plt.plot(TP12.date,TP12['dis_xy'],label='TP12')
plt.plot(TP13.date,TP13['dis_xy'],label='TP13')
plt.plot(TP14.date,TP14['dis_xy'],label='TP14')
plt.plot(TP15.date,TP15['dis_xy'],label='TP15')
plt.plot(TP18.date,TP18['dis_xy'],label='TP18')
plt.plot(TP19.date,TP19['dis_xy'],label='TP19')
plt.plot(TP20.date,TP20['dis_xy'],label='TP20')
plt.plot(TP21.date,TP21['dis_xy'],label='TP21')
plt.plot(TP22.date,TP22['dis_xy'],label='TP22')
plt.plot(TP23.date,TP23['dis_xy'],label='TP23')

plt.legend()

# %% [markdown]
# ## z向

# %%
plt.figure(figsize=(12,8))

plt.plot(TP3.date,TP3['z'],label='TP3')
plt.plot(TP5.date,TP5['z'],label='TP5')
plt.plot(TP8.date,TP8['z'],label='TP8')
plt.plot(TP9.date,TP9['z'],label='TP9')
plt.plot(TP10.date,TP10['z'],label='TP10')
plt.plot(TP11.date,TP11['z'],label='TP11')
plt.plot(TP12.date,TP12['z'],label='TP12')
plt.plot(TP13.date,TP13['z'],label='TP13')
plt.plot(TP14.date,TP14['z'],label='TP14')
plt.plot(TP15.date,TP15['z'],label='TP15')
plt.plot(TP18.date,TP18['z'],label='TP18')
plt.plot(TP19.date,TP19['z'],label='TP19')
plt.plot(TP20.date,TP20['z'],label='TP20')
plt.plot(TP21.date,TP21['z'],label='TP21')
plt.plot(TP22.date,TP22['z'],label='TP22')
plt.plot(TP23.date,TP23['z'],label='TP23')

plt.legend()

# %% [markdown]
# ## x向

# %%
plt.figure(figsize=(12,8))

plt.plot(TP3.date,TP3['x'],label='TP3')
plt.plot(TP5.date,TP5['x'],label='TP5')
plt.plot(TP8.date,TP8['x'],label='TP8')
plt.plot(TP9.date,TP9['x'],label='TP9')
plt.plot(TP10.date,TP10['x'],label='TP10')
plt.plot(TP11.date,TP11['x'],label='TP11')
plt.plot(TP12.date,TP12['x'],label='TP12')
plt.plot(TP13.date,TP13['x'],label='TP13')
plt.plot(TP14.date,TP14['x'],label='TP14')
plt.plot(TP15.date,TP15['x'],label='TP15')
plt.plot(TP18.date,TP18['x'],label='TP18')
plt.plot(TP19.date,TP19['x'],label='TP19')
plt.plot(TP20.date,TP20['x'],label='TP20')
plt.plot(TP21.date,TP21['x'],label='TP21')
plt.plot(TP22.date,TP22['x'],label='TP22')
plt.plot(TP23.date,TP23['x'],label='TP23')

plt.legend()

# %% [markdown]
# ## y向

# %%
plt.figure(figsize=(12,8))

plt.plot(TP3.date,TP3['y'],label='TP3')
plt.plot(TP5.date,TP5['y'],label='TP5')
plt.plot(TP8.date,TP8['y'],label='TP8')
plt.plot(TP9.date,TP9['y'],label='TP9')
plt.plot(TP10.date,TP10['y'],label='TP10')
plt.plot(TP11.date,TP11['y'],label='TP11')
plt.plot(TP12.date,TP12['y'],label='TP12')
plt.plot(TP13.date,TP13['y'],label='TP13')
plt.plot(TP14.date,TP14['y'],label='TP14')
plt.plot(TP15.date,TP15['y'],label='TP15')
plt.plot(TP18.date,TP18['y'],label='TP18')
plt.plot(TP19.date,TP19['y'],label='TP19')
plt.plot(TP20.date,TP20['y'],label='TP20')
plt.plot(TP21.date,TP21['y'],label='TP21')
plt.plot(TP22.date,TP22['y'],label='TP22')
plt.plot(TP23.date,TP23['y'],label='TP23')

plt.legend()
