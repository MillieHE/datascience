# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
os.chdir(r'\HCP_HP01-13_pre_result')###################adjust

# %% [markdown]
# # 数据导入

# %%
data_name=os.listdir(r'\HCP_HP01-13_pre_result')###################adjust
HP01=pd.read_excel(data_name[0],encoding='utf-8')
HP02=pd.read_excel(data_name[1],encoding='utf-8')
HP03=pd.read_excel(data_name[2],encoding='utf-8')
HP04=pd.read_excel(data_name[3],encoding='utf-8')
HP05=pd.read_excel(data_name[4],encoding='utf-8')
HP06=pd.read_excel(data_name[5],encoding='utf-8')
HP07=pd.read_excel(data_name[6],encoding='utf-8')
HP08=pd.read_excel(data_name[7],encoding='utf-8')
HP09=pd.read_excel(data_name[8],encoding='utf-8')
HP10=pd.read_excel(data_name[9],encoding='utf-8')
HP11=pd.read_excel(data_name[10],encoding='utf-8')
HP12=pd.read_excel(data_name[11],encoding='utf-8')
HP13=pd.read_excel(data_name[12],encoding='utf-8')

# %% [markdown]
# # 各点号，时间图

# %%
import matplotlib.pyplot as plt
HP01.set_index('date')[['sum_xy']].plot()
HP01.set_index('date')[['x','y','z']].plot()
HP01.set_index('date')[['x','y','z','sum_xy']].plot()

# %%
import matplotlib.pyplot as plt
HP02.set_index('date')[['sum_xy']].plot()
HP02.set_index('date')[['x','y','z']].plot()
HP02.set_index('date')[['x','y','z','sum_xy']].plot()

# %%
import matplotlib.pyplot as plt
HP03.set_index('date')[['sum_xy']].plot()
HP03.set_index('date')[['x','y','z']].plot()
HP03.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP04.set_index('date')[['sum_xy']].plot()
HP04.set_index('date')[['x','y','z']].plot()
HP04.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP05.set_index('date')[['sum_xy']].plot()
HP05.set_index('date')[['x','y','z']].plot()
HP05.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP06.set_index('date')[['sum_xy']].plot()
HP06.set_index('date')[['x','y','z']].plot()
HP06.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP07.set_index('date')[['sum_xy']].plot()
HP07.set_index('date')[['x','y','z']].plot()
HP07.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP08.set_index('date')[['sum_xy']].plot()
HP08.set_index('date')[['x','y','z']].plot()
HP08.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP09.set_index('date')[['sum_xy']].plot()
HP09.set_index('date')[['x','y','z']].plot()
HP09.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP10.set_index('date')[['sum_xy']].plot()
HP10.set_index('date')[['x','y','z','dis_xy']].plot()
HP10.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP11.set_index('date')[['sum_xy']].plot()
HP11.set_index('date')[['x','y','z','dis_xy']].plot()
HP11.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP10.set_index('date')[['sum_xy']].plot()
HP10.set_index('date')[['x','y','z']].plot()
HP10.set_index('date')[['x','y','z','dis_xy']].plot()
HP10.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP11.set_index('date')[['sum_xy']].plot()
HP11.set_index('date')[['x','y','z']].plot()
HP11.set_index('date')[['x','y','z','dis_xy']].plot()
HP11.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP12.set_index('date')[['sum_xy']].plot()
HP12.set_index('date')[['x','y','z']].plot()
HP12.set_index('date')[['x','y','z','dis_xy']].plot()
HP12.set_index('date').plot()

# %%
import matplotlib.pyplot as plt
HP13.set_index('date')[['sum_xy']].plot()
HP13.set_index('date')[['x','y','z']].plot()
HP13.set_index('date')[['x','y','z','dis_xy']].plot()
HP13.set_index('date').plot()

# %% [markdown]
# # 多点号时间图

# %% [markdown]
# ## 坡面累计位移

# %% [markdown]
# ### 整体

# %%
plt.figure(figsize=(12,8))

plt.plot(HP01.date,HP01['sum_xy'],label='HP01')
plt.plot(HP02.date,HP02['sum_xy'],label='HP02')
plt.plot(HP03.date,HP03['sum_xy'],label='HP03')
plt.plot(HP04.date,HP04['sum_xy'],label='HP04')
plt.plot(HP05.date,HP05['sum_xy'],label='HP05')
plt.plot(HP06.date,HP06['sum_xy'],label='HP06')
plt.plot(HP07.date,HP07['sum_xy'],label='HP07')
plt.plot(HP08.date,HP08['sum_xy'],label='HP08')
plt.plot(HP09.date,HP09['sum_xy'],label='HP09')
plt.plot(HP10.date,HP10['sum_xy'],label='HP10')
plt.plot(HP11.date,HP11['sum_xy'],label='HP11')
plt.plot(HP12.date,HP12['sum_xy'],label='HP12')
plt.plot(HP13.date,HP13['sum_xy'],label='HP13')

plt.legend()

#图像导出
plt.savefig(r'\HCP_pic_\HCP_xy.png',bbox_inches='tight',dpi = 1000)###################adjust

# %% [markdown]
# ### 去除HP02\03\04

# %%
plt.figure(figsize=(12,8))

plt.plot(HP01.date,HP01['sum_xy'],label='HP01')
#plt.plot(HP02.date,HP02['sum_xy'],label='HP02')
#plt.plot(HP03.date,HP03['sum_xy'],label='HP03')
#plt.plot(HP04.date,HP04['sum_xy'],label='HP04')
plt.plot(HP05.date,HP05['sum_xy'],label='HP05')
plt.plot(HP06.date,HP06['sum_xy'],label='HP06')
plt.plot(HP07.date,HP07['sum_xy'],label='HP07')
plt.plot(HP08.date,HP08['sum_xy'],label='HP08')
plt.plot(HP09.date,HP09['sum_xy'],label='HP09')
plt.plot(HP10.date,HP10['sum_xy'],label='HP10')
plt.plot(HP11.date,HP11['sum_xy'],label='HP11')
plt.plot(HP12.date,HP12['sum_xy'],label='HP12')
plt.plot(HP13.date,HP13['sum_xy'],label='HP13')

plt.legend()

#图像导出
plt.savefig(r'\HCP_pic_\HCP_xy-without234.png',bbox_inches='tight',dpi = 1000)###################adjust

# %% [markdown]
# ### 进一步去除HP05、HP08

# %%
plt.figure(figsize=(12,8))

plt.plot(HP01.date,HP01['sum_xy'],label='HP01')
#plt.plot(HP02.date,HP02['sum_xy'],label='HP02')
#plt.plot(HP03.date,HP03['sum_xy'],label='HP03')
#plt.plot(HP04.date,HP04['sum_xy'],label='HP04')
#plt.plot(HP05.date,HP05['sum_xy'],label='HP05')
plt.plot(HP06.date,HP06['sum_xy'],label='HP06')
plt.plot(HP07.date,HP07['sum_xy'],label='HP07')
#plt.plot(HP08.date,HP08['sum_xy'],label='HP08')
plt.plot(HP09.date,HP09['sum_xy'],label='HP09')
plt.plot(HP10.date,HP10['sum_xy'],label='HP10')
plt.plot(HP11.date,HP11['sum_xy'],label='HP11')
plt.plot(HP12.date,HP12['sum_xy'],label='HP12')
plt.plot(HP13.date,HP13['sum_xy'],label='HP13')

plt.legend()

#图像导出
plt.savefig(r'\HCP_pic_\HCP_xy-without23458.png',bbox_inches='tight',dpi = 1000)###################adjust

# %% [markdown]
# ### 进一步去除HP01

# %%
plt.figure(figsize=(12,8))

#plt.plot(HP01.date,HP01['sum_xy'],label='HP01')
#plt.plot(HP02.date,HP02['sum_xy'],label='HP02')
#plt.plot(HP03.date,HP03['sum_xy'],label='HP03')
#plt.plot(HP04.date,HP04['sum_xy'],label='HP04')
#plt.plot(HP05.date,HP05['sum_xy'],label='HP05')
plt.plot(HP06.date,HP06['sum_xy'],label='HP06')
plt.plot(HP07.date,HP07['sum_xy'],label='HP07')
#plt.plot(HP08.date,HP08['sum_xy'],label='HP08')
plt.plot(HP09.date,HP09['sum_xy'],label='HP09')
plt.plot(HP10.date,HP10['sum_xy'],label='HP10')
plt.plot(HP11.date,HP11['sum_xy'],label='HP11')
plt.plot(HP12.date,HP12['sum_xy'],label='HP12')
plt.plot(HP13.date,HP13['sum_xy'],label='HP13')

plt.legend()

#图像导出
plt.savefig(r'\HCP_pic_\HCP_xy-without123458.png',bbox_inches='tight',dpi = 1000)###################adjust

# %% [markdown]
# ### 进一步去除HP13

# %%
plt.figure(figsize=(12,8))

#plt.plot(HP01.date,HP01['sum_xy'],label='HP01')
#plt.plot(HP02.date,HP02['sum_xy'],label='HP02')
#plt.plot(HP03.date,HP03['sum_xy'],label='HP03')
#plt.plot(HP04.date,HP04['sum_xy'],label='HP04')
#plt.plot(HP05.date,HP05['sum_xy'],label='HP05')
plt.plot(HP06.date,HP06['sum_xy'],label='HP06')
plt.plot(HP07.date,HP07['sum_xy'],label='HP07')
#plt.plot(HP08.date,HP08['sum_xy'],label='HP08')
plt.plot(HP09.date,HP09['sum_xy'],label='HP09')
plt.plot(HP10.date,HP10['sum_xy'],label='HP10')
plt.plot(HP11.date,HP11['sum_xy'],label='HP11')
plt.plot(HP12.date,HP12['sum_xy'],label='HP12')
#plt.plot(HP13.date,HP13['sum_xy'],label='HP13')

plt.legend()

#图像导出
plt.savefig(r'\HCP_pic_\HCP_xy-without12345813.png',bbox_inches='tight',dpi = 1000)###################adjust

# %% [markdown]
# ### 匀速-增速型位移 HP08

# %% [markdown]
# #### HP08

# %%
plt.figure(figsize=(12,8))

#plt.plot(HP01.date,HP01['sum_xy'],label='HP01')
#plt.plot(HP02.date,HP02['sum_xy'],label='HP02')
#plt.plot(HP03.date,HP03['sum_xy'],label='HP03')
#plt.plot(HP04.date,HP04['sum_xy'],label='HP04')
#plt.plot(HP05.date,HP05['sum_xy'],label='HP05')
#plt.plot(HP06.date,HP06['sum_xy'],label='HP06')
#plt.plot(HP07.date,HP07['sum_xy'],label='HP07')
plt.plot(HP08.date,HP08['sum_xy'],label='HP08')
#plt.plot(HP09.date,HP09['sum_xy'],label='HP09')
#plt.plot(HP10.date,HP10['sum_xy'],label='HP10')
#plt.plot(HP11.date,HP11['sum_xy'],label='HP11')
#plt.plot(HP12.date,HP12['sum_xy'],label='HP12')
#plt.plot(HP13.date,HP13['sum_xy'],label='HP13')

plt.legend()

#图像导出
plt.savefig(r'\HCP_pic_\HCP_xy-匀速增速8.png',bbox_inches='tight',dpi = 1000)###################adjust

# %% [markdown]
# #### HP03

# %%
plt.figure(figsize=(12,8))

#plt.plot(HP01.date,HP01['sum_xy'],label='HP01')
#plt.plot(HP02.date,HP02['sum_xy'],label='HP02')
plt.plot(HP03.date,HP03['sum_xy'],label='HP03')
#plt.plot(HP04.date,HP04['sum_xy'],label='HP04')
#plt.plot(HP05.date,HP05['sum_xy'],label='HP05')
#plt.plot(HP06.date,HP06['sum_xy'],label='HP06')
#plt.plot(HP07.date,HP07['sum_xy'],label='HP07')
#plt.plot(HP08.date,HP08['sum_xy'],label='HP08')
#plt.plot(HP09.date,HP09['sum_xy'],label='HP09')
#plt.plot(HP10.date,HP10['sum_xy'],label='HP10')
#plt.plot(HP11.date,HP11['sum_xy'],label='HP11')
#plt.plot(HP12.date,HP12['sum_xy'],label='HP12')
#plt.plot(HP13.date,HP13['sum_xy'],label='HP13')

plt.legend()

#图像导出
plt.savefig(r'\HCP_pic_\HCP_xy-匀速增速3.png',bbox_inches='tight',dpi = 1000)###################adjust

# %% [markdown]
# ####  HP04

# %%
plt.figure(figsize=(12,8))

#plt.plot(HP01.date,HP01['sum_xy'],label='HP01')
#plt.plot(HP02.date,HP02['sum_xy'],label='HP02')
#plt.plot(HP03.date,HP03['sum_xy'],label='HP03')
plt.plot(HP04.date,HP04['sum_xy'],label='HP04')
#plt.plot(HP05.date,HP05['sum_xy'],label='HP05')
#plt.plot(HP06.date,HP06['sum_xy'],label='HP06')
#plt.plot(HP07.date,HP07['sum_xy'],label='HP07')
#plt.plot(HP08.date,HP08['sum_xy'],label='HP08')
#plt.plot(HP09.date,HP09['sum_xy'],label='HP09')
#plt.plot(HP10.date,HP10['sum_xy'],label='HP10')
#plt.plot(HP11.date,HP11['sum_xy'],label='HP11')
#plt.plot(HP12.date,HP12['sum_xy'],label='HP12')
#plt.plot(HP13.date,HP13['sum_xy'],label='HP13')

plt.legend()

#图像导出
plt.savefig(r'\HCP_pic_\HCP_xy-匀速增速4.png',bbox_inches='tight',dpi = 1000)###################adjust

# %% [markdown]
# ### 复合型位移 HP02

# %%
plt.figure(figsize=(12,8))

#plt.plot(HP01.date,HP01['sum_xy'],label='HP01')
plt.plot(HP02.date,HP02['sum_xy'],label='HP02')
#plt.plot(HP03.date,HP03['sum_xy'],label='HP03')
#plt.plot(HP04.date,HP04['sum_xy'],label='HP04')
#plt.plot(HP05.date,HP05['sum_xy'],label='HP05')
#plt.plot(HP06.date,HP06['sum_xy'],label='HP06')
#plt.plot(HP07.date,HP07['sum_xy'],label='HP07')
#plt.plot(HP08.date,HP08['sum_xy'],label='HP08')
#plt.plot(HP09.date,HP09['sum_xy'],label='HP09')
#plt.plot(HP10.date,HP10['sum_xy'],label='HP10')
#plt.plot(HP11.date,HP11['sum_xy'],label='HP11')
#plt.plot(HP12.date,HP12['sum_xy'],label='HP12')
#plt.plot(HP13.date,HP13['sum_xy'],label='HP13')

plt.legend()

#图像导出
plt.savefig(r'\HCP_pic_\HCP_xy-复合2.png',bbox_inches='tight',dpi = 1000)###################adjust

# %% [markdown]
# ## 坡面相对位移

# %%
plt.figure(figsize=(12,8))

plt.plot(HP01.date,HP01['dis_xy'],label='HP01')
#plt.plot(HP02.date,HP02['dis_xy'],label='HP02')
#plt.plot(HP03.date,HP03['dis_xy'],label='HP03')
#plt.plot(HP04.date,HP04['dis_xy'],label='HP04')
#plt.plot(HP05.date,HP05['dis_xy'],label='HP05')
plt.plot(HP06.date,HP06['dis_xy'],label='HP06')
plt.plot(HP07.date,HP07['dis_xy'],label='HP07')
#plt.plot(HP08.date,HP08['dis_xy'],label='HP08')
plt.plot(HP09.date,HP09['dis_xy'],label='HP09')
plt.plot(HP10.date,HP10['dis_xy'],label='HP10')
plt.plot(HP11.date,HP11['dis_xy'],label='HP11')
plt.plot(HP12.date,HP12['dis_xy'],label='HP12')
plt.plot(HP13.date,HP13['dis_xy'],label='HP13')

plt.legend()

# %% [markdown]
# ## z向

# %%
plt.figure(figsize=(12,8))

plt.plot(HP01.date,HP01['z'],label='HP01')
#plt.plot(HP02.date,HP02['z'],label='HP02')
#plt.plot(HP03.date,HP03['z'],label='HP03')
plt.plot(HP04.date,HP04['z'],label='HP04')
plt.plot(HP05.date,HP05['z'],label='HP05')
plt.plot(HP06.date,HP06['z'],label='HP06')
plt.plot(HP07.date,HP07['z'],label='HP07')
plt.plot(HP08.date,HP08['z'],label='HP08')
plt.plot(HP09.date,HP09['z'],label='HP09')
plt.plot(HP10.date,HP10['z'],label='HP10')
plt.plot(HP11.date,HP11['z'],label='HP11')
plt.plot(HP12.date,HP12['z'],label='HP12')
plt.plot(HP13.date,HP13['z'],label='HP13')

plt.legend()

# %% [markdown]
# ## x向

# %%
plt.figure(figsize=(12,8))

plt.plot(HP01.date,HP01['x'],label='HP01')
#plt.plot(HP02.date,HP02['x'],label='HP02')
#plt.plot(HP03.date,HP03['x'],label='HP03')
plt.plot(HP04.date,HP04['x'],label='HP04')
plt.plot(HP05.date,HP05['x'],label='HP05')
plt.plot(HP06.date,HP06['x'],label='HP06')
plt.plot(HP07.date,HP07['x'],label='HP07')
plt.plot(HP08.date,HP08['x'],label='HP08')
plt.plot(HP09.date,HP09['x'],label='HP09')
plt.plot(HP10.date,HP10['x'],label='HP10')
plt.plot(HP11.date,HP11['x'],label='HP11')
plt.plot(HP12.date,HP12['x'],label='HP12')
plt.plot(HP13.date,HP13['x'],label='HP13')

plt.legend()

# %% [markdown]
# ## y向

# %%
plt.figure(figsize=(12,8))

plt.plot(HP01.date,HP01['y'],label='HP01')
#plt.plot(HP02.date,HP02['y'],label='HP02')
#plt.plot(HP03.date,HP03['y'],label='HP03')
plt.plot(HP04.date,HP04['y'],label='HP04')
plt.plot(HP05.date,HP05['y'],label='HP05')
plt.plot(HP06.date,HP06['y'],label='HP06')
plt.plot(HP07.date,HP07['y'],label='HP07')
plt.plot(HP08.date,HP08['y'],label='HP08')
plt.plot(HP09.date,HP09['y'],label='HP09')
plt.plot(HP10.date,HP10['y'],label='HP10')
plt.plot(HP11.date,HP11['y'],label='HP11')
plt.plot(HP12.date,HP12['y'],label='HP12')
plt.plot(HP13.date,HP13['y'],label='HP13')

plt.legend()
