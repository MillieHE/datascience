# %%
import pandas as pd
import numpy as np
import os
os.chdir(r'\LB_TP-CX_pre_result')############adjust

# %% [markdown]
# # 数据导入

# %%
data_name=os.listdir(r'\LB_TP-CX_pre_result')############adjust
LB_0_1=pd.read_csv(data_name[0],encoding='utf-8')
LB_0_2=pd.read_csv(data_name[1],encoding='utf-8')
LB_0_3=pd.read_csv(data_name[2],encoding='utf-8')
LB_0_4=pd.read_csv(data_name[3],encoding='utf-8')
LB_1_1=pd.read_csv(data_name[4],encoding='utf-8')
LB_1_2=pd.read_csv(data_name[5],encoding='utf-8')
LB_1_3=pd.read_csv(data_name[6],encoding='utf-8')
LB_1_4=pd.read_csv(data_name[7],encoding='utf-8')
LB_1_5=pd.read_csv(data_name[8],encoding='utf-8')
LB_2_1=pd.read_csv(data_name[9],encoding='utf-8')
LB_2_2=pd.read_csv(data_name[10],encoding='utf-8')
LB_2_3=pd.read_csv(data_name[11],encoding='utf-8')
LB_2_4=pd.read_csv(data_name[12],encoding='utf-8')
LB_2_5=pd.read_csv(data_name[13],encoding='utf-8')
LB_3_1=pd.read_csv(data_name[14],encoding='utf-8')
LB_3_2=pd.read_csv(data_name[15],encoding='utf-8')
LB_3_3=pd.read_csv(data_name[16],encoding='utf-8')
LB_3_4=pd.read_csv(data_name[17],encoding='utf-8')
LB_3_5=pd.read_csv(data_name[18],encoding='utf-8')
LB_CX_1=pd.read_csv(data_name[19],encoding='utf-8')
LB_TP1=pd.read_csv(data_name[20],encoding='utf-8')
LB_TP2=pd.read_csv(data_name[21],encoding='utf-8')
LB_TP3=pd.read_csv(data_name[22],encoding='utf-8')
LB_TP4=pd.read_csv(data_name[23],encoding='utf-8')
LB_TP5=pd.read_csv(data_name[24],encoding='utf-8')
LB_XL_1=pd.read_csv(data_name[25],encoding='utf-8')
LB_XL_2=pd.read_csv(data_name[26],encoding='utf-8')

#时间处理
LB_0_1['date']=pd.to_datetime(LB_0_1['date'])
LB_0_2['date']=pd.to_datetime(LB_0_2['date'])
LB_0_3['date']=pd.to_datetime(LB_0_3['date'])
LB_0_4['date']=pd.to_datetime(LB_0_4['date'])
LB_1_1['date']=pd.to_datetime(LB_1_1['date'])
LB_1_2['date']=pd.to_datetime(LB_1_2['date'])
LB_1_3['date']=pd.to_datetime(LB_1_3['date'])
LB_1_4['date']=pd.to_datetime(LB_1_4['date'])
LB_1_5['date']=pd.to_datetime(LB_1_5['date'])
LB_2_1['date']=pd.to_datetime(LB_2_1['date'])
LB_2_2['date']=pd.to_datetime(LB_2_2['date'])
LB_2_3['date']=pd.to_datetime(LB_2_3['date'])
LB_2_4['date']=pd.to_datetime(LB_2_4['date'])
LB_2_5['date']=pd.to_datetime(LB_2_5['date'])
LB_3_1['date']=pd.to_datetime(LB_3_1['date'])
LB_3_2['date']=pd.to_datetime(LB_3_2['date'])
LB_3_3['date']=pd.to_datetime(LB_3_3['date'])
LB_3_4['date']=pd.to_datetime(LB_3_4['date'])
LB_3_5['date']=pd.to_datetime(LB_3_5['date'])
LB_CX_1['date']=pd.to_datetime(LB_CX_1['date'])
LB_TP1['date']=pd.to_datetime(LB_TP1['date'])
LB_TP2['date']=pd.to_datetime(LB_TP2['date'])
LB_TP3['date']=pd.to_datetime(LB_TP3['date'])
LB_TP4['date']=pd.to_datetime(LB_TP4['date'])
LB_TP5['date']=pd.to_datetime(LB_TP5['date'])
LB_XL_1['date']=pd.to_datetime(LB_XL_1['date'])
LB_XL_2['date']=pd.to_datetime(LB_XL_2['date'])

# %% [markdown]
# # 各点号，时间图

# %%
import matplotlib.pyplot as plt
LB_0_1.set_index('date')[['sum_xy']].plot()
LB_0_1.set_index('date')[['x','y','z']].plot()
LB_0_1.set_index('date')[['x','y','z','sum_xy']].plot()
LB_0_1.set_index('date').plot()

# %% [markdown]
# # 多点号时间图

# %% [markdown]
# ## 坡面累计位移

# %% [markdown]
# ### 整体

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))

plt.plot(LB_0_1.date,LB_0_1['sum_xy'],label='0_1')
plt.plot(LB_0_2.date,LB_0_2['sum_xy'],label='0_2')
plt.plot(LB_0_3.date,LB_0_3['sum_xy'],label='0_3')
plt.plot(LB_0_4.date,LB_0_4['sum_xy'],label='0_4')
plt.plot(LB_1_1.date,LB_1_1['sum_xy'],label='1_1')
plt.plot(LB_1_2.date,LB_1_2['sum_xy'],label='1_2')
plt.plot(LB_1_3.date,LB_1_3['sum_xy'],label='1_3')
plt.plot(LB_1_4.date,LB_1_4['sum_xy'],label='1_4')
plt.plot(LB_2_1.date,LB_2_1['sum_xy'],label='2_1')
plt.plot(LB_2_2.date,LB_2_2['sum_xy'],label='2_2')
plt.plot(LB_2_3.date,LB_2_3['sum_xy'],label='2_3')
plt.plot(LB_2_5.date,LB_2_5['sum_xy'],label='2_5')
plt.plot(LB_3_1.date,LB_3_1['sum_xy'],label='3_1')
plt.plot(LB_3_2.date,LB_3_2['sum_xy'],label='3_2')
plt.plot(LB_3_3.date,LB_3_3['sum_xy'],label='3_3')
plt.plot(LB_3_4.date,LB_3_4['sum_xy'],label='3_4')
plt.plot(LB_3_5.date,LB_3_5['sum_xy'],label='3_5')
plt.plot(LB_CX_1.date,LB_CX_1['sum_xy'],label='CX_1')
plt.plot(LB_TP1.date,LB_TP1['sum_xy'],label='TP1')
plt.plot(LB_TP2.date,LB_TP2['sum_xy'],label='TP2')
plt.plot(LB_TP3.date,LB_TP3['sum_xy'],label='TP3')
plt.plot(LB_TP4.date,LB_TP4['sum_xy'],label='TP4')
plt.plot(LB_TP5.date,LB_TP5['sum_xy'],label='TP5')
plt.plot(LB_XL_1.date,LB_XL_1['sum_xy'],label='XL_1')
plt.plot(LB_XL_2.date,LB_XL_2['sum_xy'],label='XL_2')

plt.legend()

#图像导出
plt.savefig(r'\LB_pic_\LB_xy.png',bbox_inches='tight',dpi = 1000)############adjust

# %% [markdown]
# ### CX-1

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(LB_CX_1.date,LB_CX_1['sum_xy'],label='CX_1')
plt.legend()
#图像导出
plt.savefig(r'\LB_pic_\LB_CX-1.png',bbox_inches='tight',dpi = 1000)############adjust

# %% [markdown]
# ### 0-2

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(LB_0_2.date,LB_0_2['sum_xy'],label='0_2')
plt.legend()
#图像导出
plt.savefig(r'\LB_pic_\LB_0-2.png',bbox_inches='tight',dpi = 1000)############adjust

# %% [markdown]
# ### TP3

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(LB_TP3.date,LB_TP3['sum_xy'],label='TP3')
plt.legend()
#图像导出
plt.savefig(r'\LB_pic_\LB_TP3.png',bbox_inches='tight',dpi = 1000)############adjust

# %% [markdown]
# ### CX-1、0-2、TP3

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(LB_CX_1.date,LB_CX_1['sum_xy'],label='CX_1')
plt.plot(LB_0_2.date,LB_0_2['sum_xy'],label='0_2')
plt.plot(LB_TP3.date,LB_TP3['sum_xy'],label='TP3')
plt.legend()
#图像导出
plt.savefig(r'\LB_pic_\LB_3lines.png',bbox_inches='tight',dpi = 1000)############adjust

# %% [markdown]
# ## 坡面相对位移

# %%
plt.figure(figsize=(12,8))

plt.plot(LB_0_1.date,LB_0_1['dis_xy'],label='LB_0_1')
plt.plot(LB_0_2.date,LB_0_2['dis_xy'],label='LB_0_2')
plt.plot(LB_0_3.date,LB_0_3['dis_xy'],label='LB_0_3')
plt.plot(LB_0_4.date,LB_0_4['dis_xy'],label='LB_0_4')
plt.plot(LB_1_1.date,LB_1_1['dis_xy'],label='LB_1_1')
plt.plot(LB_1_2.date,LB_1_2['dis_xy'],label='LB_1_2')
plt.plot(LB_1_3.date,LB_1_3['dis_xy'],label='LB_1_3')
plt.plot(LB_1_4.date,LB_1_4['dis_xy'],label='LB_1_4')
plt.plot(LB_2_1.date,LB_2_1['dis_xy'],label='LB_2_1')
plt.plot(LB_2_2.date,LB_2_2['dis_xy'],label='LB_2_2')
plt.plot(LB_2_3.date,LB_2_3['dis_xy'],label='LB_2_3')
plt.plot(LB_2_5.date,LB_2_5['dis_xy'],label='LB_2_5')
plt.plot(LB_3_1.date,LB_3_1['dis_xy'],label='LB_3_1')
plt.plot(LB_3_2.date,LB_3_2['dis_xy'],label='LB_3_2')
plt.plot(LB_3_3.date,LB_3_3['dis_xy'],label='LB_3_3')
plt.plot(LB_3_4.date,LB_3_4['dis_xy'],label='LB_3_4')
plt.plot(LB_3_5.date,LB_3_5['dis_xy'],label='LB_3_5')
plt.plot(LB_CX_1.date,LB_CX_1['dis_xy'],label='LB_CX_1')
plt.plot(LB_TP1.date,LB_TP1['dis_xy'],label='LB_TP1')
plt.plot(LB_TP2.date,LB_TP2['dis_xy'],label='LB_TP2')
plt.plot(LB_TP3.date,LB_TP3['dis_xy'],label='LB_TP3')
plt.plot(LB_TP4.date,LB_TP4['dis_xy'],label='LB_TP4')
plt.plot(LB_TP5.date,LB_TP5['dis_xy'],label='LB_TP5')
plt.plot(LB_XL_1.date,LB_XL_1['dis_xy'],label='LB_XL_1')
plt.plot(LB_XL_2.date,LB_XL_2['dis_xy'],label='LB_XL_2')

plt.legend()

# %% [markdown]
# ## z向

# %%
plt.figure(figsize=(12,8))

plt.plot(LB_0_1.date,LB_0_1['z'],label='LB_0_1')
plt.plot(LB_0_2.date,LB_0_2['z'],label='LB_0_2')
plt.plot(LB_0_3.date,LB_0_3['z'],label='LB_0_3')
plt.plot(LB_0_4.date,LB_0_4['z'],label='LB_0_4')
plt.plot(LB_1_1.date,LB_1_1['z'],label='LB_1_1')
plt.plot(LB_1_2.date,LB_1_2['z'],label='LB_1_2')
plt.plot(LB_1_3.date,LB_1_3['z'],label='LB_1_3')
plt.plot(LB_1_4.date,LB_1_4['z'],label='LB_1_4')
plt.plot(LB_2_1.date,LB_2_1['z'],label='LB_2_1')
plt.plot(LB_2_2.date,LB_2_2['z'],label='LB_2_2')
plt.plot(LB_2_3.date,LB_2_3['z'],label='LB_2_3')
plt.plot(LB_2_5.date,LB_2_5['z'],label='LB_2_5')
plt.plot(LB_3_1.date,LB_3_1['z'],label='LB_3_1')
plt.plot(LB_3_2.date,LB_3_2['z'],label='LB_3_2')
plt.plot(LB_3_3.date,LB_3_3['z'],label='LB_3_3')
plt.plot(LB_3_4.date,LB_3_4['z'],label='LB_3_4')
plt.plot(LB_3_5.date,LB_3_5['z'],label='LB_3_5')
plt.plot(LB_CX_1.date,LB_CX_1['z'],label='LB_CX_1')
plt.plot(LB_TP1.date,LB_TP1['z'],label='LB_TP1')
plt.plot(LB_TP2.date,LB_TP2['z'],label='LB_TP2')
plt.plot(LB_TP3.date,LB_TP3['z'],label='LB_TP3')
plt.plot(LB_TP4.date,LB_TP4['z'],label='LB_TP4')
plt.plot(LB_TP5.date,LB_TP5['z'],label='LB_TP5')
plt.plot(LB_XL_1.date,LB_XL_1['z'],label='LB_XL_1')
plt.plot(LB_XL_2.date,LB_XL_2['z'],label='LB_XL_2')

plt.legend()

# %% [markdown]
# ## x向

# %%
plt.figure(figsize=(12,8))

plt.plot(LB_0_1.date,LB_0_1['x'],label='LB_0_1')
plt.plot(LB_0_2.date,LB_0_2['x'],label='LB_0_2')
plt.plot(LB_0_3.date,LB_0_3['x'],label='LB_0_3')
plt.plot(LB_0_4.date,LB_0_4['x'],label='LB_0_4')
plt.plot(LB_1_1.date,LB_1_1['x'],label='LB_1_1')
plt.plot(LB_1_2.date,LB_1_2['x'],label='LB_1_2')
plt.plot(LB_1_3.date,LB_1_3['x'],label='LB_1_3')
plt.plot(LB_1_4.date,LB_1_4['x'],label='LB_1_4')
plt.plot(LB_2_1.date,LB_2_1['x'],label='LB_2_1')
plt.plot(LB_2_2.date,LB_2_2['x'],label='LB_2_2')
plt.plot(LB_2_3.date,LB_2_3['x'],label='LB_2_3')
plt.plot(LB_2_5.date,LB_2_5['x'],label='LB_2_5')
plt.plot(LB_3_1.date,LB_3_1['x'],label='LB_3_1')
plt.plot(LB_3_2.date,LB_3_2['x'],label='LB_3_2')
plt.plot(LB_3_3.date,LB_3_3['x'],label='LB_3_3')
plt.plot(LB_3_4.date,LB_3_4['x'],label='LB_3_4')
plt.plot(LB_3_5.date,LB_3_5['x'],label='LB_3_5')
plt.plot(LB_CX_1.date,LB_CX_1['x'],label='LB_CX_1')
plt.plot(LB_TP1.date,LB_TP1['x'],label='LB_TP1')
plt.plot(LB_TP2.date,LB_TP2['x'],label='LB_TP2')
plt.plot(LB_TP3.date,LB_TP3['x'],label='LB_TP3')
plt.plot(LB_TP4.date,LB_TP4['x'],label='LB_TP4')
plt.plot(LB_TP5.date,LB_TP5['x'],label='LB_TP5')
plt.plot(LB_XL_1.date,LB_XL_1['x'],label='LB_XL_1')
plt.plot(LB_XL_2.date,LB_XL_2['x'],label='LB_XL_2')

plt.legend()

# %% [markdown]
# ## y向

# %%
plt.figure(figsize=(12,8))

plt.plot(LB_0_1.date,LB_0_1['y'],label='LB_0_1')
plt.plot(LB_0_2.date,LB_0_2['y'],label='LB_0_2')
plt.plot(LB_0_3.date,LB_0_3['y'],label='LB_0_3')
plt.plot(LB_0_4.date,LB_0_4['y'],label='LB_0_4')
plt.plot(LB_1_1.date,LB_1_1['y'],label='LB_1_1')
plt.plot(LB_1_2.date,LB_1_2['y'],label='LB_1_2')
plt.plot(LB_1_3.date,LB_1_3['y'],label='LB_1_3')
plt.plot(LB_1_4.date,LB_1_4['y'],label='LB_1_4')
plt.plot(LB_2_1.date,LB_2_1['y'],label='LB_2_1')
plt.plot(LB_2_2.date,LB_2_2['y'],label='LB_2_2')
plt.plot(LB_2_3.date,LB_2_3['y'],label='LB_2_3')
plt.plot(LB_2_5.date,LB_2_5['y'],label='LB_2_5')
plt.plot(LB_3_1.date,LB_3_1['y'],label='LB_3_1')
plt.plot(LB_3_2.date,LB_3_2['y'],label='LB_3_2')
plt.plot(LB_3_3.date,LB_3_3['y'],label='LB_3_3')
plt.plot(LB_3_4.date,LB_3_4['y'],label='LB_3_4')
plt.plot(LB_3_5.date,LB_3_5['y'],label='LB_3_5')
plt.plot(LB_CX_1.date,LB_CX_1['y'],label='LB_CX_1')
plt.plot(LB_TP1.date,LB_TP1['y'],label='LB_TP1')
plt.plot(LB_TP2.date,LB_TP2['y'],label='LB_TP2')
plt.plot(LB_TP3.date,LB_TP3['y'],label='LB_TP3')
plt.plot(LB_TP4.date,LB_TP4['y'],label='LB_TP4')
plt.plot(LB_TP5.date,LB_TP5['y'],label='LB_TP5')
plt.plot(LB_XL_1.date,LB_XL_1['y'],label='LB_XL_1')
plt.plot(LB_XL_2.date,LB_XL_2['y'],label='LB_XL_2')

plt.legend()
